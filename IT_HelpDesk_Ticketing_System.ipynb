# %%
import sqlite3

conn = sqlite3.connect("helpdesk.db")

cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS tickets(
    ticket_id INTEGER PRIMARY KEY AUTOINCREMENT,
    employee_name TEXT,
    department TEXT,
    issue_type TEXT,
    issue_description TEXT,
    priority TEXT,
    status TEXT,
    created_date TEXT
)
""")

conn.commit()
conn.close()

print("Ticket Database Created Successfully")
# Out:
# Ticket Database Created Successfully

# %% [markdown]
# Creating Ticket

# %%
import sqlite3

conn = sqlite3.connect("helpdesk.db")
cursor = conn.cursor()

cursor.execute("""
INSERT INTO tickets
(employee_name, department, issue_type, issue_description, priority, status, created_date)
VALUES
(
'Eric Rathod',
'IT',
'Login Issue',
'Unable to login to Outlook account',
'High',
'Open',
'2026-06-04'
)
""")

conn.commit()
conn.close()

print("Ticket Created Successfully")
# Out:
# Ticket Created Successfully

# %% [markdown]
# View Tickets

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("helpdesk.db")

df = pd.read_sql_query("SELECT * FROM tickets", conn)

conn.close()

df
# Out:
#    ticket_id employee_name department   issue_type  \
# 0          1   Eric Rathod         IT  Login Issue
#
#                     issue_description priority status created_date
# 0  Unable to login to Outlook account     High   Open   2026-06-04

# %% [markdown]
# Adding  Multiple Sample Tickets

# %%
import sqlite3

conn = sqlite3.connect("helpdesk.db")
cursor = conn.cursor()

tickets = [
    ("Sara Khan","Finance","Printer Issue","Printer not responding","Medium","Open","2026-06-04"),
    ("John Smith","IT","VPN Access","Unable to connect VPN","High","In Progress","2026-06-04"),
    ("Amit Patel","HR","Password Reset","Forgot account password","Low","Closed","2026-06-04"),
    ("Priya Sharma","Operations","Software Installation","Need MS Visio installed","Medium","Open","2026-06-04")
]

cursor.executemany("""
INSERT INTO tickets
(employee_name, department, issue_type, issue_description, priority, status, created_date)
VALUES (?, ?, ?, ?, ?, ?, ?)
""", tickets)

conn.commit()
conn.close()

print("Sample Tickets Added Successfully")
# Out:
# Sample Tickets Added Successfully

# %% [markdown]
# View All Tickets

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("helpdesk.db")

df = pd.read_sql_query(
    "SELECT * FROM tickets",
    conn
)

conn.close()

df
# Out:
#    ticket_id employee_name  department             issue_type  \
# 0          1   Eric Rathod          IT            Login Issue
# 1          2     Sara Khan     Finance          Printer Issue
# 2          3    John Smith          IT             VPN Access
# 3          4    Amit Patel          HR         Password Reset
# 4          5  Priya Sharma  Operations  Software Installation
#
#                     issue_description priority       status created_date
# 0  Unable to login to Outlook account     High         Open   2026-06-04
# 1              Printer not responding   Medium         Open   2026-06-04
# 2               Unable to connect VPN     High  In Progress   2026-06-04
# 3             Forgot account password      Low       Closed   2026-06-04
# 4             Need MS Visio installed   Medium         Open   2026-06-04

# %% [markdown]
# Searching ticket

# %%
import sqlite3
import pandas as pd

employee = input("Enter employee name: ")

conn = sqlite3.connect("helpdesk.db")

query = """
SELECT *
FROM tickets
WHERE employee_name LIKE ?
"""

result = pd.read_sql_query(
    query,
    conn,
    params=('%' + employee + '%',)
)

conn.close()

result
# Out:
# Enter employee name: Eric
#    ticket_id employee_name department   issue_type  \
# 0          1   Eric Rathod         IT  Login Issue
#
#                     issue_description priority status created_date
# 0  Unable to login to Outlook account     High   Open   2026-06-04

# %% [markdown]
# Update Ticket Status

# %%
import sqlite3

ticket_id = int(input("Enter Ticket ID to update: "))
new_status = input("Enter new status (Open / In Progress / Closed): ")

conn = sqlite3.connect("helpdesk.db")
cursor = conn.cursor()

cursor.execute("""
UPDATE tickets
SET status = ?
WHERE ticket_id = ?
""", (new_status, ticket_id))

conn.commit()
conn.close()

print("Ticket Status Updated Successfully")
# Out:
# Enter Ticket ID to update: 1
# Enter new status (Open / In Progress / Closed): closed
# Ticket Status Updated Successfully

# %% [markdown]
# Delete Ticket

# %%
import sqlite3

ticket_id = int(input("Enter Ticket ID to delete: "))

conn = sqlite3.connect("helpdesk.db")
cursor = conn.cursor()

cursor.execute("""
DELETE FROM tickets
WHERE ticket_id = ?
""", (ticket_id,))

conn.commit()
conn.close()

print("Ticket Deleted Successfully")
# Out:
# Enter Ticket ID to delete: 5
# Ticket Deleted Successfully

# %% [markdown]
# Ticket Status Report

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("helpdesk.db")

query = """
SELECT
status,
COUNT(*) AS total_tickets
FROM tickets
GROUP BY status
"""

status_report = pd.read_sql_query(query, conn)

conn.close()

status_report
# Out:
#         status  total_tickets
# 0       Closed              1
# 1  In Progress              1
# 2         Open              1
# 3       closed              1

# %% [markdown]
# Priority Report

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("helpdesk.db")

query = """
SELECT
priority,
COUNT(*) AS total_tickets
FROM tickets
GROUP BY priority
"""

priority_report = pd.read_sql_query(query, conn)

conn.close()

priority_report
# Out:
#   priority  total_tickets
# 0     High              2
# 1      Low              1
# 2   Medium              1
